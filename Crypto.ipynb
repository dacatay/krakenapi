# %%
import json
import subprocess
import pandas as pd
import numpy as np

# %% [markdown]
# # Get account information

# %%
output = subprocess.getoutput('python krakenapi.py TradesHistory')
trades_dict = json.loads(output)
df = pd.DataFrame(trades_dict['result']['trades']).T

df['time'] = df['time'].apply(np.round)
df['time'] = pd.to_datetime(df['time'], unit='s').dt.strftime('%d.%m.%Y')

df.drop(['ordertxid', 'postxid', 'margin', 'misc', 'ordertype'], axis=1, inplace=True)

# RENAME
df.rename({
    'pair': 'ASSET_LONG_NAME',
    'time': 'TRANSACTION_DATE',
    'type': 'TRANSACTION_TYPE',
    'cost': 'TRANSACTION_VALUE',
    'fee': 'TRANSACTION_COST',
    'vol': 'TRANSACTION_QUANTITY',
    'price': 'TRANSACTION_PRICE'
}, axis=1, inplace=True)


df['ACCOUNT'] = 'Kraken'
df['ASSET_TYPE'] = 'crypto'

df['CURRENCY'] = df['ASSET_LONG_NAME'].str.strip().str[-3:]

df['ASSET_LONG_NAME'] = df['ASSET_LONG_NAME'].str.replace('ZEUR', '')
df['ASSET_LONG_NAME'] = df['ASSET_LONG_NAME'].str.replace('EUR', '')
df['ASSET_LONG_NAME'] = df['ASSET_LONG_NAME'].str.replace('XX', 'X')
df['ASSET_LONG_NAME'] = df['ASSET_LONG_NAME'].str.replace('XETH', 'ETH')
df['ASSET_LONG_NAME'] = df['ASSET_LONG_NAME'].str.replace('XBT', 'BTC')
df['ISIN'] = df['ASSET_LONG_NAME']

df.to_csv('fact_Transactions_kraken.csv', sep=';', index=False)


df
# Out:
#                     ASSET_LONG_NAME TRANSACTION_DATE TRANSACTION_TYPE  \
# TJXQJU-FZSSM-SWRFVO             XLM       10.02.2021              buy
# TXR74S-CX652-EDR7IH            LINK       10.02.2021              buy
# TOGEQL-5WIBW-QX3YUL             XRP       03.02.2021              buy
# TRYB6B-7BDIC-R3RYRW             XRP       03.02.2021              buy
# TFGRYQ-7L7UA-4RATRP             XRP       27.01.2021              buy
# TUS2UY-SSZDB-2DFC4S             DOT       27.01.2021              buy
# TN47O3-L7XCX-7QT5RF             XRP       27.01.2021              buy
# TFLOMZ-ATLMU-5F25RJ             DOT       27.01.2021              buy
# TUPEI5-LFP2G-SOSE5S             ETH       21.01.2021              buy
# TN55WT-UBP7A-H7BW2I             ETH       07.01.2021              buy
# TQ5LPG-KSARL-ZH7XBL             XRP       27.12.2020              buy
# TJXRPK-FQHZI-6H7K5T             BTC       17.12.2020              buy
# T2XFS6-VMUMC-G3ZG4C             DOT       03.12.2020              buy
# TSFJFD-IMIO7-NLOIDD             DOT       03.12.2020              buy
# T6V6NI-NDG5F-J5GL6U             DOT       03.12.2020              buy
# TARY7T-PHZME-5FVR2V             DOT       03.12.2020              buy
# TQULMU-ZV4SN-2NGHVZ             DOT       03.12.2020              buy
# TBZVRT-Z3E44-DH77KH             ETH       30.11.2020              buy
# TKQLKY-DTVP6-RCLPVH             XRP       30.11.2020              buy
#
#                     TRANSACTION_PRICE TRANSACTION_VALUE TRANSACTION_COST  \
# TJXQJU-FZSSM-SWRFVO        0.33500000      234.50000000       0.37520000
# TXR74S-CX652-EDR7IH         22.500000        225.000000         0.360000
# TOGEQL-5WIBW-QX3YUL        0.31700000        0.00001000       0.00000002
# TRYB6B-7BDIC-R3RYRW        0.31700000      316.99999000       0.50719998
# TFGRYQ-7L7UA-4RATRP        0.20500000       51.25000000       0.08200000
# TUS2UY-SSZDB-2DFC4S          12.80000         100.00000          0.16000
# TN47O3-L7XCX-7QT5RF        0.21400000       64.20000000       0.10272000
# TFLOMZ-ATLMU-5F25RJ          13.50000          50.00000          0.08000
# TUPEI5-LFP2G-SOSE5S        1004.00000          99.99840          0.16000
# TN55WT-UBP7A-H7BW2I         990.00000          50.00490          0.08001
# TQ5LPG-KSARL-ZH7XBL        0.22000000      112.20000000       0.17952000
# TJXRPK-FQHZI-6H7K5T       18750.00000          39.93750          0.06390
# T2XFS6-VMUMC-G3ZG4C           4.51590          81.28620          0.13006
# TSFJFD-IMIO7-NLOIDD           4.51590           0.00009          0.00000
# T6V6NI-NDG5F-J5GL6U           4.51590           0.03504          0.00006
# TARY7T-PHZME-5FVR2V           4.51590          13.51257          0.02162
# TQULMU-ZV4SN-2NGHVZ           4.51590          18.06360          0.02890
# TBZVRT-Z3E44-DH77KH         498.00000         124.50000          0.19920
# TKQLKY-DTVP6-RCLPVH        0.53647000      101.92930000       0.26501618
#
#                     TRANSACTION_QUANTITY ACCOUNT ASSET_TYPE CURRENCY  ISIN
# TJXQJU-FZSSM-SWRFVO         700.00000000  Kraken     crypto      EUR   XLM
# TXR74S-CX652-EDR7IH          10.00000000  Kraken     crypto      EUR  LINK
# TOGEQL-5WIBW-QX3YUL           0.00003154  Kraken     crypto      EUR   XRP
# TRYB6B-7BDIC-R3RYRW         999.99996846  Kraken     crypto      EUR   XRP
# TFGRYQ-7L7UA-4RATRP         250.00000000  Kraken     crypto      EUR   XRP
# TUS2UY-SSZDB-2DFC4S           7.81250000  Kraken     crypto      EUR   DOT
# TN47O3-L7XCX-7QT5RF         300.00000000  Kraken     crypto      EUR   XRP
# TFLOMZ-ATLMU-5F25RJ           3.70370370  Kraken     crypto      EUR   DOT
# TUPEI5-LFP2G-SOSE5S           0.09960000  Kraken     crypto      EUR   ETH
# TN55WT-UBP7A-H7BW2I           0.05051000  Kraken     crypto      EUR   ETH
# TQ5LPG-KSARL-ZH7XBL         510.00000000  Kraken     crypto      EUR   XRP
# TJXRPK-FQHZI-6H7K5T           0.00213000  Kraken     crypto      EUR   BTC
# T2XFS6-VMUMC-G3ZG4C          18.00000005  Kraken     crypto      EUR   DOT
# TSFJFD-IMIO7-NLOIDD           0.00002012  Kraken     crypto      EUR   DOT
# T6V6NI-NDG5F-J5GL6U           0.00775960  Kraken     crypto      EUR   DOT
# TARY7T-PHZME-5FVR2V           2.99222023  Kraken     crypto      EUR   DOT
# TQULMU-ZV4SN-2NGHVZ           4.00000000  Kraken     crypto      EUR   DOT
# TBZVRT-Z3E44-DH77KH           0.25000000  Kraken     crypto      EUR   ETH
# TKQLKY-DTVP6-RCLPVH         190.00000000  Kraken     crypto      EUR   XRP

# %% [markdown]
# # Get currency pair data

# %%
def collect_crypto_ohlc(pair='etheur', interval=15):
    """
    pair = asset pair to get OHLC data for
    interval = time frame interval in minutes (optional):
                1 (default), 5, 15, 30, 60, 240, 1440, 10080, 21600
    since = return committed OHLC data since given id (optional.  exclusive)
    """
    # QUERY THE KRAKEN API
    output = subprocess.getoutput(f'python krakenapi.py OHLC pair={pair} interval={interval}')
    json_file = json.loads(output)

    # TRANSLATE CURRENCY PAIR TO TICKER IN JSON DICT
    dict_currency = {
        'usd': 'ZUSD',
        'eur': 'ZEUR',
        'cad': 'ZCAD',
        'eth': 'XETH',
        'xbt': 'XXBT',
        'xrp': 'XXRP',
        'link': 'LINK'
    }
    ticker = pair
    for key in dict_currency.keys():
        ticker = ticker.replace(key, dict_currency[key])

    # CREATE DF FROM JSON DICT AND RENAME COLUMNS
    columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Vwap', 'Volume', 'Count']
    df = pd.DataFrame(json_file['result'][ticker], columns=columns)
    
    # FORMAT DATE AND REPLACE INDEX WITH DATE
    df['Date'] = df['Date'].apply(np.round)
    df['Date'] = pd.to_datetime(df['Date'], unit='s').dt.strftime('%d.%m.%Y %H:%M')
    df.index = df['Date']
    df.drop(['Date'], axis=1, inplace=True)

    return df

# %%
collect_crypto_ohlc(pair='ethusd', interval=15)
# Out:
#                      Open     High      Low    Close     Vwap         Volume  \
# Date
# 16.02.2021 09:00  1807.78  1807.79  1802.50  1802.60  1804.84   328.27045957
# 16.02.2021 09:15  1802.59  1802.64  1797.30  1801.26  1800.71   345.15367954
# 16.02.2021 09:30  1801.27  1801.27  1795.74  1799.69  1799.85    66.07004483
# 16.02.2021 09:45  1799.30  1803.25  1799.30  1802.50  1801.82   171.88920625
# 16.02.2021 10:00  1802.49  1804.78  1798.00  1804.15  1801.93   160.02032018
# ...                   ...      ...      ...      ...      ...            ...
# 23.02.2021 19:45  1454.06  1471.17  1447.00  1447.00  1459.27  2912.07564034
# 23.02.2021 20:00  1446.14  1478.03  1431.86  1452.00  1457.61  3675.06947903
# 23.02.2021 20:15  1452.16  1483.63  1440.14  1480.61  1462.30  2817.71255680
# 23.02.2021 20:30  1482.48  1508.51  1480.07  1505.13  1492.93  4793.30939032
# 23.02.2021 20:45  1505.12  1523.45  1499.79  1520.89  1515.73  2384.32518740
#
#                   Count
# Date
# 16.02.2021 09:00    205
# 16.02.2021 09:15    116
# 16.02.2021 09:30     78
# 16.02.2021 09:45    100
# 16.02.2021 10:00    155
# ...                 ...
# 23.02.2021 19:45   1099
# 23.02.2021 20:00   1257
# 23.02.2021 20:15   1031
# 23.02.2021 20:30    952
# 23.02.2021 20:45    707
#
# [720 rows x 7 columns]
